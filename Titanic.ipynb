# %% [markdown]
# <a href="https://colab.research.google.com/github/Reinaldo0/classificacao-titanic/blob/main/Titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Carrega os dados dos .csv
def carregar_dados():
  gender = pd.read_csv("gender_submission.csv")
  test = pd.read_csv("test.csv")
  train = pd.read_csv("train.csv")
  return train, test, gender

# Remove as linhas vazias
def limpar_dados(train, test):
  train = train.dropna()
  test = test.dropna()

  train.to_csv("train.csv")
  test.to_csv("test.csv")
  return train, test

# Explorar os dados dos .csv
def explorar_dados(dados_csv):
    print("Intervalo de linhas")
    print("\n")
    print(dados_csv.head())

    print("\nInformações")
    print("\n")
    print(dados_csv.info())

    print("\nEstatísticas descritivas")
    print("\n")
    print(dados_csv.describe())

# Seleciona as colunas
def selecionar_variaveis(train):
    colunas_analise = ['Pclass', 'Sex', 'Age', 'Fare', 'Survived']
    dados_selecionados = train[colunas_analise]
    dados_selecionados = pd.get_dummies(dados_selecionados, columns=['Sex'], drop_first=True)
    return dados_selecionados

def dividir_dados(dados_selecionados):
    X = dados_selecionados.drop('Survived', axis=1)
    y = dados_selecionados['Survived']
    return X, y

def knn_modelo(X_train, y_train):
    knn = KNeighborsClassifier(n_neighbors=3)
    knn.fit(X_train, y_train)
    return knn

def avaliar_modelo(knn, X_test, y_test):
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    print("\n")
    print(f"Acurácia do modelo: {accuracy:.2f}")
    print("\n")
    print("Relatório de classificação:")
    print("\n")
    print(classification_report(y_test, y_pred))
    print("\n")
    cm = confusion_matrix(y_test, y_pred)
    print("\n")
    print("Matriz de Confusão:")
    print(cm)
    print("\n")
    plt.figure(figsize=(8,6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Não Sobreviveu', 'Sobreviveu'], yticklabels=['Não Sobreviveu', 'Sobreviveu'])
    plt.xlabel('Previsão')
    plt.ylabel('Verdadeiro')
    plt.title('Matriz de Confusão')
    plt.show()

# Carrega os dados
train, test, gender = carregar_dados()
# Limpa as linhas vazias
train, test = limpar_dados(train, test)

# Explorar os dados
explorar_dados(train)
explorar_dados(test)
explorar_dados(gender)

# Seleciona variáveis
dados_selecionados = selecionar_variaveis(train)

# Exibir dados após seleção de variáveis
print("\n")
print("\nDados com variáveis selecionadas e categorias convertidas:")
print("\n")
print(dados_selecionados.head())

# Dividir os dados
X, y = dividir_dados(dados_selecionados)

# Treinar o modelo
model = knn_modelo(X, y)

# Avaliar o modelo
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
avaliar_modelo(model, X_test, y_test)
